# %% [markdown]
# อันนี้ของกู ไม่ต้องแก้

# %%
import pandas as pd
# Out:
# C:\Users\3lett\AppData\Local\Temp\ipykernel_12184\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df1 = pd.read_csv('Data/dict-ค่าใช้จ่ายครัวเรือน.csv')
df1
# Out:
#     _id       field_name data_type  \
# 0     1             YEAR   NUMERIC
# 1     2      CODE_REGION   NUMERIC
# 2     3           REGION      TEXT
# 3     4        CODE_AREA   NUMERIC
# 4     5             AREA      TEXT
# 5     6      MONTHLY_EXP   NUMERIC
# 6     7  CONSUMPTION_EXP   NUMERIC
# 7     8    FOOD_BEVERAGE   NUMERIC
# 8     9  ALCOHO_BEVERAGE   NUMERIC
# 9    10  TOBACCO_PRODUCT   NUMERIC
# 10   11     HH_OPERATION   NUMERIC
# 11   12          APPAREL   NUMERIC
# 12   13    PERSONAL_CARE   NUMERIC
# 13   14          MEDICAL   NUMERIC
# 14   15        TRANSPORT   NUMERIC
# 15   16        EDUCATION   NUMERIC
# 16   17       RECREATION   NUMERIC
# 17   18          SPECIAL   NUMERIC
# 18   19  NON_CONSUMPTION   NUMERIC
# 19   20             UNIT      TEXT
# 20   21           SOURCE      TEXT
#
#                                    description_thai  \
# 0                                                ปี
# 1                                           รหัสภาค
# ...

# %%
df2= pd.read_excel('Data/ข้อมูลผลการกู้ยืม แยกตามพื้นที่.xlsx')
df2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\3lett\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\3lett\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...
